# %%
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_csv("test.csv", index_col=["Id"])

# %%
df.head(3)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig      ...       ScreenPorch PoolArea  \
# Id                                        ...
# 1461         Lvl    AllPub    Inside      ...               120        0
# 1462         Lvl    AllPub    Corner      ...                 0        0
# 1463         Lvl    AllPub    Inside      ...                 0        0
#
#      PoolQC  Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  \
# Id
# 1461    NaN  MnPrv         NaN       0       6    2010        WD
# 1462    NaN    NaN        Gar2   12500       6    2010        WD
# 1463    NaN  MnPrv         NaN       0       3    2010        WD
#
#       SaleCondition
# Id
# 1461         Normal
# 1462         Normal
# ...

# %%
df.iloc[2]
# Out:
# MSSubClass            60
# MSZoning              RL
# LotFrontage           74
# LotArea            13830
# Street              Pave
# Alley                NaN
# LotShape             IR1
# LandContour          Lvl
# Utilities         AllPub
# LotConfig         Inside
# LandSlope            Gtl
# Neighborhood     Gilbert
# Condition1          Norm
# Condition2          Norm
# BldgType            1Fam
# HouseStyle        2Story
# OverallQual            5
# OverallCond            5
# YearBuilt           1997
# YearRemodAdd        1998
# RoofStyle          Gable
# RoofMatl         CompShg
# Exterior1st      VinylSd
# Exterior2nd      VinylSd
# MasVnrType          None
# MasVnrArea             0
# ExterQual             TA
# ExterCond             TA
# Foundation         PConc
# BsmtQual              Gd
#                   ...
# HalfBath               1
# BedroomAbvGr           3
# KitchenAbvGr           1
# KitchenQual           TA
# TotRmsAbvGrd           6
# Functional           Typ
# ...

# %%
df.loc[1463]
# Out:
# MSSubClass            60
# MSZoning              RL
# LotFrontage           74
# LotArea            13830
# Street              Pave
# Alley                NaN
# LotShape             IR1
# LandContour          Lvl
# Utilities         AllPub
# LotConfig         Inside
# LandSlope            Gtl
# Neighborhood     Gilbert
# Condition1          Norm
# Condition2          Norm
# BldgType            1Fam
# HouseStyle        2Story
# OverallQual            5
# OverallCond            5
# YearBuilt           1997
# YearRemodAdd        1998
# RoofStyle          Gable
# RoofMatl         CompShg
# Exterior1st      VinylSd
# Exterior2nd      VinylSd
# MasVnrType          None
# MasVnrArea             0
# ExterQual             TA
# ExterCond             TA
# Foundation         PConc
# BsmtQual              Gd
#                   ...
# HalfBath               1
# BedroomAbvGr           3
# KitchenAbvGr           1
# KitchenQual           TA
# TotRmsAbvGrd           6
# Functional           Typ
# ...

# %%
df.loc[[1462,1463]]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig      ...       ScreenPorch PoolArea  \
# Id                                        ...
# 1462         Lvl    AllPub    Corner      ...                 0        0
# 1463         Lvl    AllPub    Inside      ...                 0        0
#
#      PoolQC  Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  \
# Id
# 1462    NaN    NaN        Gar2   12500       6    2010        WD
# 1463    NaN  MnPrv         NaN       0       3    2010        WD
#
#       SaleCondition
# Id
# 1462         Normal
# 1463         Normal
#
# [2 rows x 79 columns]

# %%
df.iloc[[2,4,3]]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig      ...       ScreenPorch PoolArea  \
# Id                                        ...
# 1463         Lvl    AllPub    Inside      ...                 0        0
# 1465         HLS    AllPub    Inside      ...               144        0
# 1464         Lvl    AllPub    Inside      ...                 0        0
#
#      PoolQC  Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  \
# Id
# 1463    NaN  MnPrv         NaN       0       3    2010        WD
# 1465    NaN    NaN         NaN       0       1    2010        WD
# 1464    NaN    NaN         NaN       0       6    2010        WD
#
#       SaleCondition
# Id
# 1463         Normal
# 1465         Normal
# ...

# %%
df[:3]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig      ...       ScreenPorch PoolArea  \
# Id                                        ...
# 1461         Lvl    AllPub    Inside      ...               120        0
# 1462         Lvl    AllPub    Corner      ...                 0        0
# 1463         Lvl    AllPub    Inside      ...                 0        0
#
#      PoolQC  Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  \
# Id
# 1461    NaN  MnPrv         NaN       0       6    2010        WD
# 1462    NaN    NaN        Gar2   12500       6    2010        WD
# 1463    NaN  MnPrv         NaN       0       3    2010        WD
#
#       SaleCondition
# Id
# 1461         Normal
# 1462         Normal
# ...

# %%
df[3:6]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
# 1466          60       RL         75.0    10000   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig      ...       ScreenPorch PoolArea  \
# Id                                        ...
# 1464         Lvl    AllPub    Inside      ...                 0        0
# 1465         HLS    AllPub    Inside      ...               144        0
# 1466         Lvl    AllPub    Corner      ...                 0        0
#
#      PoolQC Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# Id
# 1464    NaN   NaN         NaN       0       6    2010        WD         Normal
# 1465    NaN   NaN         NaN       0       1    2010        WD         Normal
# 1466    NaN   NaN         NaN       0       4    2010        WD         Normal
#
# ...

# %%
df["Condition1"].head(3)
# Out:
# Id
# 1461    Feedr
# 1462     Norm
# 1463     Norm
# Name: Condition1, dtype: object

# %%
df.Condition1.head(5)
# Out:
# Id
# 1461    Feedr
# 1462     Norm
# 1463     Norm
# 1464     Norm
# 1465     Norm
# Name: Condition1, dtype: object

# %%
df[["Condition1", "Condition2"]][:6]
# Out:
#      Condition1 Condition2
# Id
# 1461      Feedr       Norm
# 1462       Norm       Norm
# 1463       Norm       Norm
# 1464       Norm       Norm
# 1465       Norm       Norm
# 1466       Norm       Norm

# %%
df.Condition1.iloc[2]
# Out:
# 'Norm'

# %%
df.Condition1.iloc[[2]]
# Out:
# Id
# 1463    Norm
# Name: Condition1, dtype: object

# %%
(df.Condition1 == "Norm").head(4)
# Out:
# Id
# 1461    False
# 1462     True
# 1463     True
# 1464     True
# Name: Condition1, dtype: bool

# %%
df[df.Condition1 == "Feedr"].head(15)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1492          30       RH         70.0     9800   Pave   NaN      Reg
# 1518          90       RL         70.0     8267   Pave   NaN      Reg
# 1542          50       RM         53.0     5830   Pave   NaN      Reg
# 1544          30       RM         50.0     5000   Pave   NaN      Reg
# 1547          50       RM         53.0     6360   Pave   NaN      Reg
# 1555          20       RL        100.0    15263   Pave   NaN      IR1
# 1567          30       RL         94.0     9259   Pave   NaN      Reg
# 1586          30       RL         67.0     8777   Pave   NaN      Reg
# 1595          50       RL         51.0     9839   Pave   NaN      Reg
# 1732          20       RL          NaN     8499   Pave   NaN      IR1
# 1736          20       RL         65.0     7150   Pave   NaN      Reg
# ...

# %%
df[df.Condition1.isin(["Norm", "Feedr"])]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
# 1466          60       RL         75.0    10000   Pave   NaN      IR1
# 1467          20       RL          NaN     7980   Pave   NaN      IR1
# 1468          60       RL         63.0     8402   Pave   NaN      IR1
# 1469          20       RL         85.0    10176   Pave   NaN      Reg
# 1470          20       RL         70.0     8400   Pave   NaN      Reg
# 1471         120       RH         26.0     5858   Pave   NaN      IR1
# 1472         160       RM         21.0     1680   Pave   NaN      Reg
# ...

# %%
df["Condition1"].value_counts().plot.bar()

# %%
df["SaleCondition"].value_counts().plot.hist()
